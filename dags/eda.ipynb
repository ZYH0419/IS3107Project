# %%
import pandas as pd

# %%
df = pd.read_parquet("combined_training_df.parquet")

# %%
df.head()
# Out:
#    link_id  speed_band  minimum_speed  maximum_speed  \
# 0        2           4           30.0           39.0
# 1        2           4           30.0           39.0
# 2        2           4           30.0           39.0
# 3        2           4           30.0           39.0
# 4        2           4           30.0           39.0
#
#                collected_at  current_speed_band  avg_speed  \
# 0 2026-04-26 01:35:40+00:00                   4       34.5
# 1 2026-04-26 03:27:53+00:00                   4       34.5
# 2 2026-04-26 03:30:44+00:00                   4       34.5
# 3 2026-04-26 03:35:00+00:00                   4       34.5
# 4 2026-04-26 03:40:02+00:00                   4       34.5
#
#    current_congestion_score  road_category station_id  ... hour_of_day  \
# 0                         5              5        S79  ...           1
# 1                         5              5        S79  ...           3
# ...
