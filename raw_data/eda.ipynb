# %%
import pandas as pd

df = pd.read_parquet("traffic_speed_snapshot_20260418_150726.parquet")
print(df.head())
# Out:
#    link_id  speed_band  minimum_speed  maximum_speed
# 0        2           4           30.0           39.0
# 1        3           1            0.0            9.0
# 2        4           1            0.0            9.0
# 3        5           1            0.0            9.0
# 4        6           2           10.0           19.0
